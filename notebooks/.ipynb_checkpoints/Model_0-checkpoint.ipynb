# %% [markdown]
# # Model 0
# #### Model: XGBOOSt
# #### Dataset(s): Fuser
# Description: We have fuser data preprocessed we will be building and running a simple xgboost model on it

# %% [markdown]
# ### Imports and Boiler-Plate

# %%
import pandas as pd

# %%
FUSER_JFK_PATH = '/projectnb/cs640grp/projects/noahark/preprocess/train/fuser/KJFK'

# %%
from pathlib import Path
file_paths = [str(f) for f in Path(FUSER_JFK_PATH).rglob("*") if f.is_file()]
print("\n".join(file_paths))
# Out:
# /projectnb/cs640grp/projects/noahark/preprocess/train/fuser/KJFK/MFS_df.parquet
# /projectnb/cs640grp/projects/noahark/preprocess/train/fuser/KJFK/TBFM_df.parquet
# /projectnb/cs640grp/projects/noahark/preprocess/train/fuser/KJFK/runway_df.parquet
# /projectnb/cs640grp/projects/noahark/preprocess/train/fuser/KJFK/tfm_df.parquet

# %% [markdown]
# ## Basic Look at the Data

# %%
df = pd.read_parquet(file_paths[0])
df
# Out:
#                                      aircraft_engine_class aircraft_type  \
# gufi
# AAL1199.MIA.JFK.221110.2100.0250.TFM                   JET          B38M
# JBU2124.LAX.JFK.221111.0445.0041.TFM                   JET          A321
# ABX152.JFK.CVG.221112.0137.0006.TFM                    JET          B763
# AIC101.DEL.JFK.221110.2015.0157.TFM                    JET          B77W
# JBU1852.CUN.JFK.221110.2020.0070.TFM                   JET          A321
# ...                                                    ...           ...
# VIR138.JFK.LHR.230122.0200.0062.TFM                    JET          A35K
# BAW176A.JFK.LHR.230122.0025.0154.TFM                   JET          B772
# AAL1280.PHX.JFK.230122.0650.0023.TFM                   JET          B38M
# CES588.JFK.PVG.230122.2025.0077.TFM                    JET          B77W
# AAL293.DEL.JFK.230121.1825.0065.TFM                    JET          B77W
#
#                                      arrival_aerodrome_icao_name  \
# gufi
# AAL1199.MIA.JFK.221110.2100.0250.TFM                        KJFK
# JBU2124.LAX.JFK.221111.0445.0041.TFM                        KJFK
# ABX152.JFK.CVG.221112.0137.0006.TFM                         KCVG
# AIC101.DEL.JFK.221110.2015.0157.TFM                         KJFK
# JBU1852.CUN.JFK.221110.2020.0070.TFM                        KJFK
# ...                                                          ...
# VIR138.JFK.LHR.230122.0200.0062.TFM                         EGLL
# BAW176A.JFK.LHR.230122.0025.0154.TFM                        EGLL
# AAL1280.PHX.JFK.230122.0650.0023.TFM                        KJFK
# CES588.JFK.PVG.230122.2025.0077.TFM                         ZSPD
# AAL293.DEL.JFK.230121.1825.0065.TFM                         KJFK
#
#                                      major_carrier              flight_type
# gufi
# AAL1199.MIA.JFK.221110.2100.0250.TFM           AAL  SCHEDULED_AIR_TRANSPORT
# JBU2124.LAX.JFK.221111.0445.0041.TFM           JBU  SCHEDULED_AIR_TRANSPORT
# ABX152.JFK.CVG.221112.0137.0006.TFM           None                      NaN
# AIC101.DEL.JFK.221110.2015.0157.TFM           None  SCHEDULED_AIR_TRANSPORT
# JBU1852.CUN.JFK.221110.2020.0070.TFM           JBU  SCHEDULED_AIR_TRANSPORT
# ...                                            ...                      ...
# VIR138.JFK.LHR.230122.0200.0062.TFM           None  SCHEDULED_AIR_TRANSPORT
# BAW176A.JFK.LHR.230122.0025.0154.TFM          None  SCHEDULED_AIR_TRANSPORT
# AAL1280.PHX.JFK.230122.0650.0023.TFM           AAL  SCHEDULED_AIR_TRANSPORT
# CES588.JFK.PVG.230122.2025.0077.TFM           None  SCHEDULED_AIR_TRANSPORT
# AAL293.DEL.JFK.230121.1825.0065.TFM            AAL  SCHEDULED_AIR_TRANSPORT
#
# [432622 rows x 5 columns]

# %%
df = pd.read_parquet(file_paths[1])
df
# Out:
#                                      arrival_runway_sta_time_stamp  \
# gufi
# EDV5392.PWM.JFK.230520.2330.0039.TFM           2023-05-22 00:00:00
# JBU1692.LIR.JFK.230520.2100.0201.TFM           2023-05-22 00:00:00
# EVA32.TPE.JFK.230520.1110.0121.TFM             2023-05-22 00:00:00
# JBU1858.AUA.JFK.230520.2100.0192.TFM           2023-05-22 00:00:00
# JBU852.CUN.JFK.230520.2210.0087.TFM            2023-05-22 00:00:00
# ...                                                            ...
# RPA5654.ORD.JFK.220907.2345.0105.TFM           2022-09-09 00:59:34
# RPA5654.ORD.JFK.220907.2345.0105.TFM           2022-09-09 00:59:39
# RPA4623.CMH.JFK.220907.2335.0067.TFM           2022-09-09 00:59:44
# RPA5654.ORD.JFK.220907.2345.0105.TFM           2022-09-09 00:59:51
# GLG7392.GYE.JFK.220908.1930.0001.TFM           2022-09-09 00:59:57
#
#                                        arrival_runway_sta
# gufi
# EDV5392.PWM.JFK.230520.2330.0039.TFM  2023-05-22 00:26:26
# JBU1692.LIR.JFK.230520.2100.0201.TFM  2023-05-22 01:28:52
# EVA32.TPE.JFK.230520.1110.0121.TFM    2023-05-22 02:34:38
# JBU1858.AUA.JFK.230520.2100.0192.TFM  2023-05-22 01:22:27
# JBU852.CUN.JFK.230520.2210.0087.TFM   2023-05-22 01:34:10
# ...                                                   ...
# RPA5654.ORD.JFK.220907.2345.0105.TFM  2022-09-09 01:41:00
# RPA5654.ORD.JFK.220907.2345.0105.TFM  2022-09-09 01:41:22
# RPA4623.CMH.JFK.220907.2335.0067.TFM  2022-09-09 01:33:59
# RPA5654.ORD.JFK.220907.2345.0105.TFM  2022-09-09 01:41:43
# GLG7392.GYE.JFK.220908.1930.0001.TFM  2022-09-09 03:07:44
#
# [139688701 rows x 2 columns]

# %%
df = pd.read_parquet(file_paths[2])
df
